# %% [markdown]
# <a href="https://colab.research.google.com/github/nana-lyj/sentiment-polarity/blob/main/CHAPTER_5_HEATMAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# # ST

# %%
# Load the data from a CSV file (change the file path to match your own data)
data = pd.read_csv('https://raw.githubusercontent.com/nana-lyj/sentiment/main/STHEATMAP.tsv', sep='\t')

# %%
# Create a pivot table with the sentiment scores for each sentence
pivot_table = data.pivot_table(values=['positive', 'neutral', 'negative'], index='sentence')

# Normalize the sentiment scores to a range of 0 to 1
normalized_table = (pivot_table - pivot_table.min()) / (pivot_table.max() - pivot_table.min())

# Convert the pivot table to a NumPy array for clustering
X = pivot_table.values

# Perform k-means clustering with 50 clusters
kmeans = KMeans(n_clusters=20)
kmeans.fit(X)

# Get the cluster assignments for each row
labels = kmeans.labels_

# Add the cluster assignments to the pivot table as a new column
pivot_table['Cluster'] = labels

# Create a pivot table with the mean sentiment scores for each cluster
cluster_means = pivot_table.pivot_table(values=['positive', 'neutral', 'negative'], index='Cluster', aggfunc='mean')

# Normalize the sentiment scores to a range of 0 to 1
normalized_means = (cluster_means - cluster_means.min()) / (cluster_means.max() - cluster_means.min())

# Create the plot with higher resolution
fig = plt.figure(figsize=(10, 8), dpi=200)

# Create a heatmap using Seaborn
sns.heatmap(normalized_means, cmap='RdBu', center=0)

# Set the plot title and axis labels
plt.title('ST Sentiment Polarity Heatmap')
plt.xlabel('Sentiment Category')
plt.ylabel('Cluster')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-10-50d958bfbeb9>:12: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   kmeans.fit(X)

# %% [markdown]
# # TT1909

# %%
# Load the data from a CSV file (change the file path to match your own data)
data = pd.read_csv('https://raw.githubusercontent.com/nana-lyj/sentiment/main/TT1909HEATMAP.tsv', sep='\t')

# %%
# Create a pivot table with the sentiment scores for each sentence
pivot_table = data.pivot_table(values=['positive', 'neutral', 'negative'], index='sentence')

# Normalize the sentiment scores to a range of 0 to 1
normalized_table = (pivot_table - pivot_table.min()) / (pivot_table.max() - pivot_table.min())

# Convert the pivot table to a NumPy array for clustering
X = pivot_table.values

# Perform k-means clustering with 50 clusters
kmeans = KMeans(n_clusters=20)
kmeans.fit(X)

# Get the cluster assignments for each row
labels = kmeans.labels_

# Add the cluster assignments to the pivot table as a new column
pivot_table['Cluster'] = labels

# Create a pivot table with the mean sentiment scores for each cluster
cluster_means = pivot_table.pivot_table(values=['positive', 'neutral', 'negative'], index='Cluster', aggfunc='mean')

# Normalize the sentiment scores to a range of 0 to 1
normalized_means = (cluster_means - cluster_means.min()) / (cluster_means.max() - cluster_means.min())

# Create the plot with higher resolution
fig = plt.figure(figsize=(10, 8), dpi=200)

# Create a heatmap using Seaborn
sns.heatmap(normalized_means, cmap='RdBu', center=0)

# Set the plot title and axis labels
plt.title('TT1909 Sentiment Polarity Heatmap')
plt.xlabel('Sentiment Category')
plt.ylabel('Cluster')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-12-7b121c4b333c>:12: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   kmeans.fit(X)

# %% [markdown]
# # TT1948

# %%
# Load the data from a CSV file (change the file path to match your own data)
data = pd.read_csv('https://raw.githubusercontent.com/nana-lyj/sentiment/main/TT1948HEATMAP.tsv', sep='\t')

# %%
# Create a pivot table with the sentiment scores for each sentence
pivot_table = data.pivot_table(values=['positive', 'neutral', 'negative'], index='sentence')

# Normalize the sentiment scores to a range of 0 to 1
normalized_table = (pivot_table - pivot_table.min()) / (pivot_table.max() - pivot_table.min())

# Convert the pivot table to a NumPy array for clustering
X = pivot_table.values

# Perform k-means clustering with 50 clusters
kmeans = KMeans(n_clusters=20)
kmeans.fit(X)

# Get the cluster assignments for each row
labels = kmeans.labels_

# Add the cluster assignments to the pivot table as a new column
pivot_table['Cluster'] = labels

# Create a pivot table with the mean sentiment scores for each cluster
cluster_means = pivot_table.pivot_table(values=['positive', 'neutral', 'negative'], index='Cluster', aggfunc='mean')

# Normalize the sentiment scores to a range of 0 to 1
normalized_means = (cluster_means - cluster_means.min()) / (cluster_means.max() - cluster_means.min())

# Create the plot with higher resolution
fig = plt.figure(figsize=(10, 8), dpi=200)

# Create a heatmap using Seaborn
sns.heatmap(normalized_means, cmap='RdBu', center=0)

# Set the plot title and axis labels
plt.title('TT1948 Sentiment Polarity Heatmap')
plt.xlabel('Sentiment Category')
plt.ylabel('Cluster')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-14-4f2444a2bc04>:12: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   kmeans.fit(X)

# %% [markdown]
# # TT2018

# %%
# Load the data from a CSV file (change the file path to match your own data)
data = pd.read_csv('https://raw.githubusercontent.com/nana-lyj/sentiment/main/TT2018HEATMAP.tsv', sep='\t')

# %%
# Create a pivot table with the sentiment scores for each sentence
pivot_table = data.pivot_table(values=['positive', 'neutral', 'negative'], index='sentence')

# Normalize the sentiment scores to a range of 0 to 1
normalized_table = (pivot_table - pivot_table.min()) / (pivot_table.max() - pivot_table.min())

# Convert the pivot table to a NumPy array for clustering
X = pivot_table.values

# Perform k-means clustering with 50 clusters
kmeans = KMeans(n_clusters=20)
kmeans.fit(X)

# Get the cluster assignments for each row
labels = kmeans.labels_

# Add the cluster assignments to the pivot table as a new column
pivot_table['Cluster'] = labels

# Create a pivot table with the mean sentiment scores for each cluster
cluster_means = pivot_table.pivot_table(values=['positive', 'neutral', 'negative'], index='Cluster', aggfunc='mean')

# Normalize the sentiment scores to a range of 0 to 1
normalized_means = (cluster_means - cluster_means.min()) / (cluster_means.max() - cluster_means.min())

# Create the plot with higher resolution
fig = plt.figure(figsize=(10, 8), dpi=200)

# Create a heatmap using Seaborn
sns.heatmap(normalized_means, cmap='RdBu', center=0)

# Set the plot title and axis labels
plt.title('TT2018 Sentiment Polarity Heatmap')
plt.xlabel('Sentiment Category')
plt.ylabel('Cluster')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-16-fd66ffb87417>:12: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   kmeans.fit(X)
